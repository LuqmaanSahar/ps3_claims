# %% [markdown]
# Notebook for quickly testing new functions.

# %%
from glum import GeneralizedLinearRegressor, TweedieDistribution

# %%
from dask_ml.preprocessing import Categorizer

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


from lightgbm import LGBMRegressor
from sklearn.compose import ColumnTransformer
from sklearn.metrics import auc
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, SplineTransformer, StandardScaler
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from dask_ml.preprocessing import Categorizer
#       5 from glum import GeneralizedLinearRegressor, TweedieDistribution
#       6 from lightgbm import LGBMRegressor
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/dask_ml/__init__.py:2
#       1 # Ensure we always register tokenizers
# ----> 2 from dask_ml.model_selection import _normalize  # noqa: F401
#       4 from ._version import __version__
#       6 __all__ = ["__version__"]
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/dask_ml/model_selection/__init__.py:7
#       1 """Utilities for hyperparameter optimization.
#       2
#       3 These estimators will operate in parallel. Their scalability depends
#       4 on the underlying estimators being used.
#       5 """
# ----> 7 from ._hyperband import HyperbandSearchCV
#       8 from ._incremental import IncrementalSearchCV, InverseDecaySearchCV
#       9 from ._search import GridSearchCV, RandomizedSearchCV, check_cv, compute_n_splits
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/dask_ml/model_selection/_hyperband.py:10
#       7 from warnings import warn
#       9 import numpy as np
# ---> 10 from sklearn.utils import check_random_state
#      12 from ._incremental import BaseIncrementalSearchCV
#      13 from ._successive_halving import SuccessiveHalvingSearchCV
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/_array_api.py:20
#      18 from ..externals import array_api_extra as xpx
#      19 from ..externals.array_api_compat import numpy as np_compat
# ---> 20 from .fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/sklearn/utils/fixes.py:16
#      14 import scipy
#      15 import scipy.sparse.linalg
# ---> 16 import scipy.stats
#      17 from scipy import optimize
#      19 try:
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/stats/__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/stats/_stats_py.py:56
#      53 from ._stats import (_kendall_dis, _toint64, _weightedrankedtau,
#      54                      _local_correlations)
#      55 from dataclasses import dataclass, field
# ---> 56 from ._hypotests import _all_partitions
#      57 from ._stats_pythran import _compute_outer_prob_inside_method
#      58 from ._resampling import (MonteCarloMethod, PermutationMethod, BootstrapMethod,
#      59                           monte_carlo_test, permutation_test, bootstrap,
#      60                           _batch_generator)
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/stats/_hypotests.py:13
#      11 from ._continuous_distns import chi2, norm
#      12 from scipy.special import gamma, kv, gammaln
# ---> 13 from scipy.fft import ifft
#      14 from ._stats_pythran import _a_ij_Aij_Dij2
#      15 from ._stats_pythran import (
#      16     _concordant_pairs as _P, _discordant_pairs as _Q
#      17 )
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/fft/__init__.py:85
#       1 """
#       2 ==============================================
#       3 Discrete Fourier transforms (:mod:`scipy.fft`)
#    (...)
#      82
#      83 """
# ---> 85 from ._basic import (
#      86     fft, ifft, fft2, ifft2, fftn, ifftn,
#      87     rfft, irfft, rfft2, irfft2, rfftn, irfftn,
#      88     hfft, ihfft, hfft2, ihfft2, hfftn, ihfftn)
#      89 from ._realtransforms import dct, idct, dst, idst, dctn, idctn, dstn, idstn
#      90 from ._fftlog import fht, ifht, fhtoffset
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/fft/_basic.py:1
# ----> 1 from scipy._lib.uarray import generate_multimethod, Dispatchable
#       2 import numpy as np
#       5 def _x_replacer(args, kwargs, dispatchables):
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/_lib/uarray.py:28
#      26     from uarray import _Function
#      27 else:
# ---> 28     from ._uarray import *  # noqa: F403
#      29     from ._uarray import _Function  # noqa: F401
#      31 del _has_uarray
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/_lib/_uarray/__init__.py:115
#       1 """
#       2 .. note:
#       3     If you are looking for overrides for NumPy-specific methods, see the
#    (...)
#     112 will not be possible.
#     113 """
# --> 115 from ._backend import *
#     116 __version__ = '0.8.8.dev0+aa94c5a4.scipy'
#
# File ~/miniconda3/envs/ps3/lib/python3.12/site-packages/scipy/_lib/_uarray/_backend.py:5
#       3 import inspect
#       4 import functools
# ----> 5 from . import _uarray
#       6 import copyreg
#       7 import pickle
#
# KeyboardInterrupt:

# %%
from ps3.data import load_transform

# %%
df = load_transform()

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0      1        0      0.10    D         5       0        5          50
# 1      3        0      0.77    D         5       0        5          50
# 2      5        0      0.75    B         6       1        5          50
# 3     10        0      0.09    B         7       0        4          50
# 4     11        0      0.84    B         7       0        4          50
#
#   VehBrand   VehGas  Density Region  ClaimAmount  ClaimAmountCut
# 0      B12  Regular     1217    R82          0.0             0.0
# 1      B12  Regular     1217    R82          0.0             0.0
# 2      B12   Diesel       54    R22          0.0             0.0
# 3      B12   Diesel       76    R72          0.0             0.0
# 4      B12   Diesel       76    R72          0.0             0.0

# %%
from ps3.data import create_sample_split

# %%
df_split = create_sample_split(df, "IDpol")
df_split.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0      1        0      0.10    D         5       0        5          50
# 1      3        0      0.77    D         5       0        5          50
# 2      5        0      0.75    B         6       1        5          50
# 3     10        0      0.09    B         7       0        4          50
# 4     11        0      0.84    B         7       0        4          50
#
#   VehBrand   VehGas  Density Region  ClaimAmount  ClaimAmountCut sample
# 0      B12  Regular     1217    R82          0.0             0.0  train
# 1      B12  Regular     1217    R82          0.0             0.0  train
# 2      B12   Diesel       54    R22          0.0             0.0  train
# 3      B12   Diesel       76    R72          0.0             0.0  train
# 4      B12   Diesel       76    R72          0.0             0.0  train
